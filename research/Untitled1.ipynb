# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
import torch

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16559, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (24/24), done.
# ^Cceiving objects:  12% (2014/16559), 932.00 KiB | 42.00 KiB/s
# fetch-pack: unexpected disconnect while reading sideband packet

# %%
# %cd yolov5
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /Users/rajeshgolchha/Desktop/research/yolov5

# %%
# !python train.py --img 416 --batch 16 --epochs 30 --data data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=415, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 8 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-296-gae4ef3b2 Python-3.11.5 torch-2.2.2 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# WARNING ⚠️ --img-size 415 must be multiple of max stride 32, updating to 416
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /Users/rajeshgolchha/Desktop/research/dataset/labels/train.cache
# train: Caching images (0.3GB ram): 100%|██████████| 779/779 [00:01<00:00, 405.72
# val: Scanning /Users/rajeshgolchha/Desktop/research/dataset/labels/valid.cache..
# val: Caching images (0.1GB ram): 100%|██████████| 337/337 [00:02<00:00, 140.54it
#
# AutoAnchor: 4.64 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# Image sizes 416 train, 416 val
# Using 4 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/29         0G     0.1018    0.02715    0.03308         52        416: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.859      0.247       0.21     0.0596
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/29         0G    0.07811    0.02631    0.01997         35        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.922      0.277      0.361      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/29         0G    0.07306    0.02225    0.01481         40        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.551      0.422      0.306     0.0904
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/29         0G    0.06571    0.01979    0.01171         31        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.547      0.507      0.359      0.161
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/29         0G    0.06002    0.01795   0.008956         58        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.734      0.446      0.502      0.236
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/29         0G     0.0538    0.01643   0.007343         34        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.621      0.706      0.613      0.237
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/29         0G    0.04964    0.01604   0.006555         35        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.603      0.684      0.611      0.304
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/29         0G    0.04702    0.01547    0.00566         44        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.615      0.755      0.641      0.328
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/29         0G    0.04505    0.01512   0.005459         44        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.818      0.795      0.817      0.447
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/29         0G    0.04315    0.01449   0.004953         38        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.862      0.836       0.87      0.418
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/29         0G    0.04081    0.01404    0.00493         26        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.784      0.848      0.791      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/29         0G    0.03988    0.01442    0.00451         42        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.866       0.85      0.851      0.444
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/29         0G    0.03965    0.01385   0.004441         50        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.864      0.859      0.869      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/29         0G    0.03854    0.01392   0.004121         48        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.857      0.884      0.888      0.492
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/29         0G    0.03665    0.01334   0.003952         37        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.934      0.888      0.925      0.499
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/29         0G    0.03559    0.01327   0.003811         37        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.923      0.886      0.908      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/29         0G    0.03519    0.01329   0.003681         49        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.926      0.884      0.927      0.507
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/29         0G    0.03441    0.01281   0.003661         51        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.899      0.886      0.907      0.513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/29         0G     0.0339    0.01295   0.003591         36        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.921        0.9      0.934      0.511
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/29         0G    0.03258     0.0127   0.003545         41        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.938      0.907      0.939       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/29         0G    0.03334    0.01285   0.003544         34        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684       0.92       0.88      0.909      0.509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/29         0G    0.03192    0.01278   0.003044         35        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.936      0.899      0.931       0.52
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/29         0G    0.03144    0.01251   0.003322         40        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.944      0.924      0.941       0.54
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/29         0G    0.03016    0.01192   0.002523         41        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.941      0.909      0.936      0.527
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/29         0G    0.03093    0.01246   0.003158         47        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.936      0.917      0.942      0.527
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/29         0G    0.02981    0.01218   0.002859         31        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.934      0.903      0.923      0.531
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/29         0G    0.02938    0.01188   0.003152         47        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.948       0.93      0.943      0.547
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/29         0G    0.02889    0.01186   0.002843         44        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684       0.95      0.933      0.951      0.553
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/29         0G    0.02854    0.01185   0.002885         52        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.948      0.924      0.938      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/29         0G    0.02871    0.01155   0.002631         41        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684      0.953      0.927      0.941      0.546
#
# 30 epochs completed in 9.779 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.3MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        337        684       0.95      0.933      0.951      0.555
#                 mobile        337        138      0.868       0.86      0.874      0.345
#               seatbelt        337        208      0.985      0.941      0.985      0.465
# Exception in thread Thread-25 (plot_mc_curve):
# Exception in thread Thread-24 (plot_pr_curve):
# Traceback (most recent call last):
#             windshield        337        338      0.998      0.997      0.995      0.856
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# Traceback (most recent call last):
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/threading.py", line 975, in run
#     self.run()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rajeshgolchha/Desktop/research/yolov5/utils/metrics.py", line 365, in plot_mc_curve
#     fig, ax = plt.subplots(1, 1, figsize=(9, 6), tight_layout=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py", line 1502, in subplots
#     self._target(*self._args, **self._kwargs)
#   File "/Users/rajeshgolchha/Desktop/research/yolov5/utils/metrics.py", line 342, in plot_pr_curve
#     fig, ax = plt.subplots(1, 1, figsize=(9, 6), tight_layout=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py", line 1502, in subplots
#     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py", line 917, in subplots
#     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py", line 917, in subplots
#     axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/gridspec.py", line 299, in subplots
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/gridspec.py", line 299, in subplots
#     axarr[row, col] = figure.add_subplot(
#                       ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py", line 768, in add_subplot
#     axarr[row, col] = figure.add_subplot(
#                       ^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/figure.py", line 768, in add_subplot
#     ax = projection_class(self, *args, **pkw)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 683, in __init__
#     ax = projection_class(self, *args, **pkw)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 661, in __init__
#     self.clear()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 1395, in clear
#     self.set_subplotspec(subplotspec)
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 793, in set_subplotspec
#     self._set_position(subplotspec.get_position(self.figure))
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 1143, in _set_position
#     self.__clear()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py", line 1367, in __clear
#     for ax in self._twinned_axes.get_siblings(self):
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py", line 887, in get_siblings
#     self._shared_axes["y"].clean()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py", line 841, in clean
#     val = mapping.pop(key)
#           ^^^^^^^^^^^^^^^^
# KeyError: <weakref at 0x151f74e50; dead>
#     self.clean()
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py", line 839, in clean
#     to_drop = [key for key in mapping if key() is None]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/rajeshgolchha/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py", line 839, in <listcomp>
#     to_drop = [key for key in mapping if key() is None]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: dictionary changed size during iteration
# Results saved to runs/train/exp4
